# %%
import pandas as pd

# %%
df = pd.read_csv('Data/animal_crossing.csv')

# %%
df.head()
# Out:
#               name     variation body_title  pattern  pattern_title diy  \
# 0  Admiral's photo  Natural wood      Frame      NaN            NaN  No
# 1  Admiral's photo     Dark wood      Frame      NaN            NaN  No
# 2  Admiral's photo        Pastel      Frame      NaN            NaN  No
# 3  Admiral's photo         White      Frame      NaN            NaN  No
# 4  Admiral's photo           Pop      Frame      NaN            NaN  No
#
#   customize  kit_cost  buy  sell color_1 color_2 size           source  \
# 0       Yes       1.0  NFS  10.0   Green    Blue  1x1  High Friendship
# 1       Yes       1.0  NFS  10.0   Green    Blue  1x1  High Friendship
# 2       Yes       1.0  NFS  10.0   Green    Blue  1x1  High Friendship
# 3       Yes       1.0  NFS  10.0   Green    Blue  1x1  High Friendship
# 4       Yes       1.0  NFS  10.0   Green    Blue  1x1  High Friendship
#
#   version         catalog                       filename variant_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             100 non-null    object
#  1   variation        100 non-null    object
#  2   body_title       100 non-null    object
#  3   pattern          0 non-null      float64
#  4   pattern_title    0 non-null      float64
#  5   diy              100 non-null    object
#  6   customize        100 non-null    object
#  7   kit_cost         100 non-null    float64
#  8   buy              100 non-null    object
#  9   sell             100 non-null    float64
#  10  color_1          100 non-null    object
#  11  color_2          100 non-null    object
#  12  size             100 non-null    object
#  13  source           100 non-null    object
#  14  version          100 non-null    object
#  15  catalog          100 non-null    object
# ...
